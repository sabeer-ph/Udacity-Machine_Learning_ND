# %% [markdown]
# ### 01. Intro
#
# Support Vector Machines are very powerful algorithms for classification that not only aims to classify the data but also aims to find the best boundary. mainly the one that maintains the largest distance from the points. Lets see how it works.

# %% [markdown]
# ### 02. Which line is better?
#
# ![Quiz1.%20which%20line%20better.PNG](attachment:Quiz1.%20which%20line%20better.PNG)
#
# **Answer :** the one on the left yellow line as the distance between the points are more. the line on the right is too close to the point and there is more chnace of mis classification.

# %% [markdown]
# ### 03. Minimizing Distances
#
# ![QUiz%20Answer%20justification..PNG](attachment:QUiz%20Answer%20justification..PNG)
#
# So how do we know yellow is the best line : so we extract the distance between closest points to the line in both the lines. and we take the 2 smallest distance of yellow and blue line. then with 2 distance we check which one is the farest and that wins.

# %% [markdown]
# ### 04. Error Function Intuition
#
# Nomral classificattion algorith finds a line to split the data but we want a bit more . i.e we want a boundary with margin as wide as possible.
# ![Error%20Function.PNG](attachment:Error%20Function.PNG)

# %% [markdown]
# there are 2 ways to measure this model 1) how many points were misclassified and 2 ) how wide the margin is.
#
# in the above case 2 points were misclasified . Also 4 points were within the margin so added to classification error. So the error will be the total of classification error + margin error.

# %% [markdown]
# ### 05. Perceptron Algorithm
#
# Let's recall something we've seen before: The perceptron algorithm. Before, we saw it as a trick in which we started with a random line, and iterated on a step in order to slowly walk the line towards the misclassified points, so we can classify them correctly. However, we can also see this algorithm as an algorithm which minimizes an error function. Here's the way to do this:
#
# ![Error%20calculation%20sample.PNG](attachment:Error%20calculation%20sample.PNG)
#
# for error calculation absolute values of error are taken.

# %% [markdown]
# ### 06. Classification Error
#
# ![Classification%20error.PNG](attachment:Classification%20error.PNG)

# %% [markdown]
# ### incomplete

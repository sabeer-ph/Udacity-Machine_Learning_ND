# %% [markdown]
# ### 01. Intro
#
# Is used to solve clasification problem where the answer is YES or No i.e email spam or not. Is the patient sick or not.
# The first algorithm we learn is Perceptron Algorithm . This is also a basis of neural network

# %% [markdown]
# ### 02. Classification Problems 1
#
# Problem 1: is Acceptance of students for a university based on Test score and grades.
#
# A student with test 9 and grade 8 gets accepted
#
# A student with test score 3 and grade 4 gets rejected
#
# Question is a student with test score 7 and grade 6 will be accepted or not???
#
# **Answer is YES. We plot all the historical data of accepted and rejected students. Red is rejected and blue is accepted and we draw a line to separte the red and blue. then we plot this 3rd student and its will be in the blue region above the line hence accepted as per the model**

# %% [markdown]
# ### 03. Classification Problems 2
#
# From below picture we notice that a line is drawn to nicely split the accepted and rejected students. However there are a few mis classification it is neglected for now. as the 3rd student is above the line he gets accepted
#
# ![Quiz-1.PNG](attachment:Quiz-1.PNG)
#
# The question here is how to find this line. thats is what we will be learning here.

# %% [markdown]
# ### 04. Linear Boundaries
#
# First we will be name the horizontal axis as X1 and vertical axis as x2. the equation of the line drawn is as shown.
# For all new students we solve this equation. if we get postive number we accept the students and reject otherwise
#
# ![the%20line%20equation.PNG](attachment:the%20line%20equation.PNG)

# %% [markdown]
# The equation of the line in general is w1x1+w2x2+b = 0
#
# the same equation in vector notation is wx+b =0
#
# ![General-line-equation-2.PNG](attachment:General-line-equation-2.PNG)
#
# where w1,w2 are weights.
#
# x1,x2 are inputs
#
# b is bias
#
# y is the label i.e is 1 if accepted 0 not accepted.
#
# out prediction y hat is 1 if the equation solves to more than zero and 0 otherwise
#
# Summary : The points above the line has y hat 1 and points below is y hat 0. The blue points has y = 1 and red is y = 0. the goal of the algorithm is to make y hat resembling y as closely as possible which is exactly equal to finding the boundary line which keeps most of the blue point above and red below it.

# %% [markdown]
# ### 05. Higher Dimensions
#
# In the previous case we had just test and grade. what will happen if we have more than 2 data columns say 3. test , grade and rank.
#
# the difference here is instead of 2d we will now working in 3d and instead of boundary line we will have a plane.
#
# ![Higher-Dimesnion.PNG](attachment:Higher-Dimesnion.PNG)
#
# so no matter how many columns of data we have. the prediction is the same. below picture gives details on N data points

# %% [markdown]
# ![N-Dimesnion.PNG](attachment:N-Dimesnion.PNG)

# %% [markdown]
# ### 06. Perceptrons
#
# Perceptrons is the building block of neural network and is just an encoding of equation into a small graph. there are 2 ways how we can build a graph.
#
# ![Perceptron.PNG](attachment:Perceptron.PNG)
#
# Given Score = 2*Test + 1*Grade - 18, suppose w1 was 1.5 instead of 2. Would the student who got 7 on the test and 6 on the grades be accepted or rejected?
#
# 1.5 * 7 + 6 - 18 = -1.5   # rejected

# %% [markdown]
# ### 07. Perceptrons as Logical Operators
#
# In this lesson, we'll see one of the many great applications of perceptrons. As logical operators! You'll have the chance to create the perceptrons for the most common of these, the AND, OR, and NOT operators. And then, we'll see what to do about the elusive XOR operator. Let's dive in!
#
# ##### AND
#
# ![AND-perceptron.PNG](attachment:AND-perceptron.PNG)

# %% [markdown]
# ##### OR
#
# ![OR-perceptron.PNG](attachment:OR-perceptron.PNG)

# %% [markdown]
# Quiz : What are the weights and bias for the AND perceptron?
#
# Set the weights (weight1, weight2) and bias (bias) to values that will correctly determine the AND operation as shown above.
# More than one set of values will work!

# %%
import pandas as pd

# TODO: Set weight1, weight2, and bias
weight1 = 1.0
weight2 = 1.0
bias = -1.5


# DON'T CHANGE ANYTHING BELOW
# Inputs and outputs
test_inputs = [(0, 0), (0, 1), (1, 0), (1, 1)]
correct_outputs = [False, False, False, True]
outputs = []

# Generate and check output
for test_input, correct_output in zip(test_inputs, correct_outputs):
    linear_combination = weight1 * test_input[0] + weight2 * test_input[1] + bias
    output = int(linear_combination >= 0)
    is_correct_string = 'Yes' if output == correct_output else 'No'
    outputs.append([test_input[0], test_input[1], linear_combination, output, is_correct_string])

# Print output
num_wrong = len([output[4] for output in outputs if output[4] == 'No'])
output_frame = pd.DataFrame(outputs, columns=['Input 1', '  Input 2', '  Linear Combination', '  Activation Output', '  Is Correct'])
if not num_wrong:
    print('Nice!  You got it all correct.\n')
else:
    print('You got {} wrong.  Keep trying!\n'.format(num_wrong))
print(output_frame.to_string(index=False))
# Out:
# Nice!  You got it all correct.
#
#  Input 1    Input 2    Linear Combination    Activation Output   Is Correct
#        0          0                  -1.5                    0          Yes
#        0          1                  -0.5                    0          Yes
#        1          0                  -0.5                    0          Yes
#        1          1                   0.5                    1          Yes

# %% [markdown]
# ##### Quiz : What are the weights and bias for the OR perceptron?
#
# The OR perceptron is very similar to an AND perceptron. In the image above, the OR perceptron has the same line as the AND perceptron, except the line is shifted down. What can you do to the weights and/or bias to achieve this? Use the following AND perceptron to create an OR Perceptron.
#
# SOLUTION:
# Increase the weights
#
# Decrease the magnitude of the bias

# %%
import pandas as pd

# TODO: Set weight1, weight2, and bias
weight1 = 2.7
weight2 = 2.0
bias = -1.5


# DON'T CHANGE ANYTHING BELOW
# Inputs and outputs
test_inputs = [(0, 0), (0, 1), (1, 0), (1, 1)]
correct_outputs = [False, True, True, True]
outputs = []

# Generate and check output
for test_input, correct_output in zip(test_inputs, correct_outputs):
    linear_combination = weight1 * test_input[0] + weight2 * test_input[1] + bias
    output = int(linear_combination >= 0)
    is_correct_string = 'Yes' if output == correct_output else 'No'
    outputs.append([test_input[0], test_input[1], linear_combination, output, is_correct_string])

# Print output
num_wrong = len([output[4] for output in outputs if output[4] == 'No'])
output_frame = pd.DataFrame(outputs, columns=['Input 1', '  Input 2', '  Linear Combination', '  Activation Output', '  Is Correct'])
if not num_wrong:
    print('Nice!  You got it all correct.\n')
else:
    print('You got {} wrong.  Keep trying!\n'.format(num_wrong))
print(output_frame.to_string(index=False))
# Out:
# Nice!  You got it all correct.
#
#  Input 1    Input 2    Linear Combination    Activation Output   Is Correct
#        0          0                  -1.5                    0          Yes
#        0          1                   0.5                    1          Yes
#        1          0                   1.2                    1          Yes
#        1          1                   3.2                    1          Yes

# %% [markdown]
# ##### NOT Perceptron
# Unlike the other perceptrons we looked at, the NOT operation only cares about one input. The operation returns a 0 if the input is 1 and a 1 if it's a 0. The other inputs to the perceptron are ignored.
#
# In this quiz, you'll set the weights (weight1, weight2) and bias bias to the values that calculate the NOT operation on the second input and ignores the first input.

# %%
import pandas as pd

# TODO: Set weight1, weight2, and bias
weight1 = 0.0
weight2 = -2.0
bias = 1.0


# DON'T CHANGE ANYTHING BELOW
# Inputs and outputs
test_inputs = [(0, 0), (0, 1), (1, 0), (1, 1)]
correct_outputs = [True, False, True, False]
outputs = []

# Generate and check output
for test_input, correct_output in zip(test_inputs, correct_outputs):
    linear_combination = weight1 * test_input[0] + weight2 * test_input[1] + bias
    output = int(linear_combination >= 0)
    is_correct_string = 'Yes' if output == correct_output else 'No'
    outputs.append([test_input[0], test_input[1], linear_combination, output, is_correct_string])

# Print output
num_wrong = len([output[4] for output in outputs if output[4] == 'No'])
output_frame = pd.DataFrame(outputs, columns=['Input 1', '  Input 2', '  Linear Combination', '  Activation Output', '  Is Correct'])
if not num_wrong:
    print('Nice!  You got it all correct.\n')
else:
    print('You got {} wrong.  Keep trying!\n'.format(num_wrong))
print(output_frame.to_string(index=False))

# %% [markdown]
# ### 08. Perceptron Trick
#
# In the last section you used your logic and your mathematical knowledge to create perceptrons for some of the most common logical operators. In real life, though, we can't be building these perceptrons ourselves. The idea is that we give them the result, and they build themselves. For this, here's a pretty neat trick that will help us.
#
# ![Mis-Clasify-Quiz.PNG](attachment:Mis-Clasify-Quiz.PNG)
#
# #### Time for some math!
# Now that we've learned that the points that are misclassified, want the line to move closer to them, let's do some math. The following video shows a mathematical trick that modifies the equation of the line, so that it comes closer to a particular point.

# %% [markdown]
# the line gives us 2 regions one is positive >0 and negative < 0. we have a misclassified point (4,5)which wants the line to come closer.
#
# The question is how do we make the line move closer to the point. Thats where the trick is used. We assume the bias to be 1. and we subtract the x and y and bias values from the equation values. this new line will move towards the point and possibly move over the point and classify it properly.
#
# ![Perceptron-Trick.PNG](attachment:Perceptron-Trick.PNG)
#
# however we will not move the line drastically as there is a high chance we might classify so many other points. we want the line to take small steps towards the point. Thats why we introduce learning rate.

# %% [markdown]
# so instead of subreacting 4 5 and 1 from the equation values. we multiply 4,6 and 1 with 0.1 giving 0.4, 0.5 and 0.1
#
# ![Perceptron-Trick-learningrate.PNG](attachment:Perceptron-Trick-learningrate.PNG)

# %% [markdown]
# #### case 2 : if a positive point is in the negative region (instead of subtracting we add values)
#
# ![Perceptron-Trick-postivevalue%20in%20negative%20side.PNG](attachment:Perceptron-Trick-postivevalue%20in%20negative%20side.PNG)

# %% [markdown]
# ### 09. Perceptron Algorithm
#
# And now, with the perceptron trick in our hands, we can fully develop the perceptron algorithm! The following video will show you the pseudocode, and in the quiz below, you'll have the chance to code it in Python.
#
# ![Algorithm-for-moving-line.PNG](attachment:Algorithm-for-moving-line.PNG)
#
# Coding the Perceptron Algorithm
#
# Recall that the perceptron step works as follows. For a point with coordinates
# (p,q)(p,q), label yy, and prediction given by the equation \hat{y} = step(w_1x_1 + w_2x_2 + b)
# y
# ^
# ​
#  =step(w
# 1
# ​
#  x
# 1
# ​
#  +w
# 2
# ​
#  x
# 2
# ​
#  +b):
#
# If the point is correctly classified, do nothing.
# If the point is classified positive, but it has a negative label, subtract
# \alpha p, \alpha q,αp,αq, and
# \alphaα
# from
# w_1, w_2,w
# 1
# ​
#  ,w
# 2
# ​
#  ,
# and
# bb
# respectively.
# If the point is classified negative, but it has a positive label, add
# \alpha p, \alpha q,αp,αq,
# and
# \alphaα
# to
# w_1, w_2,w
# 1
# ​
#  ,w
# 2
# ​
#  ,
# and
# bb
# respectively.

# %%
import numpy as np
import pandas as pd
# Setting the random seed, feel free to change it and see different solutions.
np.random.seed(42)

def stepFunction(t):
    if t >= 0:
        return 1
    return 0

def prediction(X, W, b):
    return stepFunction((np.matmul(X,W)+b)[0])

# TODO: Fill in the code below to implement the perceptron trick.
# The function should receive as inputs the data X, the labels y,
# the weights W (as an array), and the bias b,
# update the weights and bias W, b, according to the perceptron algorithm,
# and return W and b.
def perceptronStep(X, y, W, b, learn_rate = 0.01):
    # Fill in code
    for i in range(len(X)):
        y_hat = prediction(X[i],W,b)
        if y[i]-y_hat == 1:
            W[0] += X[i][0]*learn_rate
            W[1] += X[i][1]*learn_rate
            b += learn_rate
        elif y[i]-y_hat == -1:
            W[0] -= X[i][0]*learn_rate
            W[1] -= X[i][1]*learn_rate
            b -= learn_rate
    return W, b
    
# This function runs the perceptron algorithm repeatedly on the dataset,
# and returns a few of the boundary lines obtained in the iterations,
# for plotting purposes.
# Feel free to play with the learning rate and the num_epochs,
# and see your results plotted below.
def trainPerceptronAlgorithm(X, y, learn_rate = 0.01, num_epochs = 25):
    x_min, x_max = min(X.T[0]), max(X.T[0])
    y_min, y_max = min(X.T[1]), max(X.T[1])
    W = np.array(np.random.rand(2,1))
    b = np.random.rand(1)[0] + x_max
    # These are the solution lines that get plotted below.
    boundary_lines = []
    for i in range(num_epochs):
        # In each epoch, we apply the perceptron step.
        W, b = perceptronStep(X, y, W, b, learn_rate)
        boundary_lines.append((-W[0]/W[1], -b/W[1]))
    return boundary_lines

# %%
import pandas as pd
data = pd.read_csv('./Data/data.csv',header=None)

X = data[[0,1]].values
y = data[2].values

trainPerceptronAlgorithm(X,y)
# Out:
# [(array([-0.05239463]), array([-2.04919443])),
#  (array([1.23772563]), array([-2.90815949])),
#  (array([-39.47663703]), array([23.57864461])),
#  (array([-13.13237331]), array([7.06473087])),
#  (array([-9.11612538]), array([4.57527519])),
#  (array([-7.79056954]), array([3.96940892])),
#  (array([-6.7750263]), array([3.50523881])),
#  (array([-5.97212608]), array([3.13826056])),
#  (array([-5.32141098]), array([2.84084093])),
#  (array([-4.78335796]), array([2.59491529])),
#  (array([-4.33103935]), array([2.38817591])),
#  (array([-4.09146109]), array([2.3928177])),
#  (array([-3.80251597]), array([2.25914697])),
#  (array([-3.54414571]), array([2.13962066])),
#  (array([-3.31174122]), array([2.03210655])),
#  (array([-3.10157551]), array([1.93488045])),
#  (array([-2.91060228]), array([1.84653311])),
#  (array([-2.73630733]), array([1.76590142])),
#  (array([-2.57659722]), array([1.69201691])),
#  (array([-2.4297148]), array([1.6240667])),
# ...
